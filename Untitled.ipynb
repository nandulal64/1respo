# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/hrdata.csv')
# Out:
#              Name  HireDate   Salary  SickDaysremaining
# 0  Graham Chapman  03/15/14  50000.0                 10
# 1     John Cleese  06/01/15  65000.0                  8
# 2       Eric Idle  05/12/14  45000.0                 10
# 3     Terry Jones  11/01/13  70000.0                  3
# 4   Terry Gilliam  08/12/14  48000.0                  7
# 5   Michael Palin  05/23/13  66000.0                  8

# %%
pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/train_datamart.csv')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
pd.read_excel(r'C:\Users\nandu\OneDrive\Desktop\data science\1.xlsx')
# Out:
#    Item_Identifier Item_Weight Item_Fat_Content Item_Visibility Item_Type  \
# 0                0       FDA15              9.3         Low Fat  0.016047
# 1                1       DRC01             5.92         Regular  0.019278
# 2                2       FDN15             17.5         Low Fat   0.01676
# 3                3       FDX07             19.2         Regular         0
# 4                4       NCD19             8.93         Low Fat         0
# 5              ...         ...              ...             ...       ...
# 6             8518       FDF22            6.865         Low Fat  0.056783
# 7             8519       FDS36             8.38         Regular  0.046982
# 8             8520       NCJ29             10.6         Low Fat  0.035186
# 9             8521       FDN46             7.21         Regular  0.145221
# 10            8522       DRG01             14.8         Low Fat  0.044878
#
#                  Item_MRP Outlet_Identifier Outlet_Establishment_Year  \
# ...

# %%
pd.read_csv(r'C:\Users\nandu\OneDrive\Desktop\data science\2.csv')
# Out:
#    Item_Identifier Item_Weight Item_Fat_Content Item_Visibility Item_Type  \
# 0                0       FDA15              9.3         Low Fat  0.016047
# 1                1       DRC01             5.92         Regular  0.019278
# 2                2       FDN15             17.5         Low Fat   0.01676
# 3                3       FDX07             19.2         Regular         0
# 4                4       NCD19             8.93         Low Fat         0
# 5              ...         ...              ...             ...       ...
# 6             8518       FDF22            6.865         Low Fat  0.056783
# 7             8519       FDS36             8.38         Regular  0.046982
# 8             8520       NCJ29             10.6         Low Fat  0.035186
# 9             8521       FDN46             7.21         Regular  0.145221
# 10            8522       DRG01             14.8         Low Fat  0.044878
#
#                  Item_MRP Outlet_Identifier Outlet_Establishment_Year  \
# ...
